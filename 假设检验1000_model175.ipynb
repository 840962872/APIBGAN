# %%
from math import sqrt

import numpy as np
import pandas as pd
import torch
from numpy import array
from pandas import DataFrame
from sklearn import preprocessing
from torch import nn
from torch.autograd import Variable

# 读取文件
data = pd.read_csv('yanfa_test_norm.csv',encoding="GB2312")

result_list = []

class generator(nn.Module):
    def __init__(self):
        super(generator, self).__init__()
        self.gen = nn.Sequential(
            nn.Linear(4, 256),  # 用线性变换将噪声映射到10个特征
            nn.ReLU(True),  # relu激活
            nn.Linear(256, 256),  # 线性变换
            nn.ReLU(True),  # relu激活
            nn.Linear(256, 10),  # 线性变换
        )

    def forward(self, x):
        x = self.gen(x)
        return x
for modeli in range(50):
    a = torch.load("model//generator_175th.pth").cuda()
    z = Variable(torch.randn(100, 4)).cuda()
    b = a(z).tolist()
    # print(b)
    data1 = DataFrame(b, columns=['day','hour','minute',
                'account_switchIP', 
                    'account_IP__count', 'account_url__count','account_switchIP__count',
                        'account_url_IP__count','url_IP_switchIP__count','ret'])
    #b.to_csv("..//Generator_data.csv", encoding="GB2312")

    for i in range(len(data1['ret'])):
        #print(i)
        if data1['ret'][i] > 1 or data1['ret'][i] < 0:
            #print(data['ret'][i])
            data1.drop(axis=0, index=i, inplace=True)


    test_data = data[['day','hour','minute',
                'account_switchIP', 
                    'account_IP__count', 'account_url__count','account_switchIP__count',
                        'account_url_IP__count','url_IP_switchIP__count','ret']]
    test_data = DataFrame(test_data, columns=['day','hour','minute',
                'account_switchIP', 
                    'account_IP__count', 'account_url__count','account_switchIP__count',
                        'account_url_IP__count','url_IP_switchIP__count','ret'])

    '''min_max_scaler = preprocessing.MinMaxScaler()
    test_data = min_max_scaler.fit_transform(test_data)
    #print(train_data)
    test_data = DataFrame(test_data, columns=[ 'hour',
                              'account_IP', 'account_url', 'account_switchIP', 'account_url_IP',
                              'url_IP_switchIP', 'account_IP__count', 'account_url__count',
                                  'account_switchIP__count',
                              'account_url_IP__count','url_IP_switchIP__count','ret'])
    '''


    predict_list = []
    for diyi in range(len(test_data)):
        b = test_data.iloc[diyi].tolist()
        del (b[-1])
        dis_list = []
        for m in range(len(data1)):
            temp = data1.iloc[m].tolist()
            del (temp[-1])
            dis_list.append(np.sqrt(np.sum(np.square(array(b) - array(temp)))))
        # print(dis_list)
        # print(dis_list.index(min(dis_list)))
        # 打印每一个ret的预测值
        #print(data1.iloc[dis_list.index(min(dis_list))].tolist()[-1])
        predict_list.append(data1.iloc[dis_list.index(min(dis_list))].tolist()[-1])

    test_data.insert(10, 'predict_ret', predict_list)

    # 得分
    score = DataFrame((test_data['ret'].to_numpy() - test_data['predict_ret'].to_numpy()) ** 2)
    print("这是第{}次的训练，最终得分为：".format(modeli+1))
    result_list.append(1 / (1 + sqrt(score.sum(axis=0) / score.count())))
    print(1 / (1 + sqrt(score.sum(axis=0) / score.count())))

    # test_data.to_csv("假设检验结果1000//第{}th_score{}.csv".format(modeli+1, 1 / (1 + sqrt(score.sum(axis=0) / score.count()))),
    #                  index=None, encoding='GB2312')
DataFrame(result_list).to_csv("假设检验结果100//最终结果.csv",encoding='UTF-8')
# Out:
# 这是第1次的训练，最终得分为：
# 0.8678258826377689
# 这是第2次的训练，最终得分为：
# 0.8652037136336296
# 这是第3次的训练，最终得分为：
# 0.8629979306665816
# 这是第4次的训练，最终得分为：
# 0.8636635326751821
# 这是第5次的训练，最终得分为：
# 0.8665574319075552
# 这是第6次的训练，最终得分为：
# 0.8710687925168545
# 这是第7次的训练，最终得分为：
# 0.8687967363710076
# 这是第8次的训练，最终得分为：
# 0.8607218358532015
# 这是第9次的训练，最终得分为：
# 0.8647696566622465
# 这是第10次的训练，最终得分为：
# 0.8660038830880616
# 这是第11次的训练，最终得分为：
# 0.8595140030661705
# 这是第12次的训练，最终得分为：
# 0.8589032787538484
# 这是第13次的训练，最终得分为：
# 0.8659796984766387
# 这是第14次的训练，最终得分为：
# 0.8678039323195404
# 这是第15次的训练，最终得分为：
# 0.8675705050663005
# 这是第16次的训练，最终得分为：
# 0.8666653069492325
# 这是第17次的训练，最终得分为：
# 0.8649894835477234
# 这是第18次的训练，最终得分为：
# 0.8643401246813666
# 这是第19次的训练，最终得分为：
# 0.8600659880379244
# 这是第20次的训练，最终得分为：
# 0.8593166706077785
# 这是第21次的训练，最终得分为：
# 0.8670493044991268
# 这是第22次的训练，最终得分为：
# 0.8554300292277944
# 这是第23次的训练，最终得分为：
# 0.8611988104384738
# 这是第24次的训练，最终得分为：
# 0.8570725427709422
# 这是第25次的训练，最终得分为：
# 0.8622006126599197
# 这是第26次的训练，最终得分为：
# 0.8679275451743395
# 这是第27次的训练，最终得分为：
# 0.8625538410127142
# 这是第28次的训练，最终得分为：
# 0.8662155601723888
# 这是第29次的训练，最终得分为：
# 0.8592340305613354
# 这是第30次的训练，最终得分为：
# 0.8667912411169594
# 这是第31次的训练，最终得分为：
# 0.8613902468792118
# 这是第32次的训练，最终得分为：
# 0.8571279101033287
# 这是第33次的训练，最终得分为：
# 0.8660278276867323
# 这是第34次的训练，最终得分为：
# 0.869783757306971
# 这是第35次的训练，最终得分为：
# 0.8665387535285628
# 这是第36次的训练，最终得分为：
# 0.8690832813141908
# 这是第37次的训练，最终得分为：
# 0.866371945428981
# 这是第38次的训练，最终得分为：
# 0.8625813436879245
# 这是第39次的训练，最终得分为：
# 0.864288802152478
# 这是第40次的训练，最终得分为：
# 0.8643200415282623
# 这是第41次的训练，最终得分为：
# 0.8644144899767606
# 这是第42次的训练，最终得分为：
# 0.8693527553575505
# 这是第43次的训练，最终得分为：
# 0.8694758209394567
# 这是第44次的训练，最终得分为：
# 0.8645427562416621
# 这是第45次的训练，最终得分为：
# 0.8651053640327749
# 这是第46次的训练，最终得分为：
# 0.8670699914401867
# 这是第47次的训练，最终得分为：
# 0.8610251911058217
# 这是第48次的训练，最终得分为：
# 0.8581923274231114
# 这是第49次的训练，最终得分为：
# 0.8614155029036248
# 这是第50次的训练，最终得分为：
# 0.8606484772055971
